# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("1d_out_particle_data_0001.csv")

# %%
# T_hist = np.histogram(data, bins=50, density=True)
# v_range = np.linspace(-5000, 5000, 1000)
# alpha_vals = u_alpha_hist[0]
# alpha_centers = (u_alpha_hist[1][1:] + u_alpha_hist[1][:-1]) / 2
# alpha_widths = u_alpha_hist[1][1:] - u_alpha_hist[1][:-1]

# plt.figure()
# plt.bar(alpha_centers, alpha_vals * 1e4, alpha_widths, edgecolor='black', label="Samples")
# plt.plot(x_alpha_range, stats.norm.pdf(x_alpha_range, 0, sigma_alpha) * 1e4, 'k', label="$\\mathcal{N}\\left(0, \\sigma_\\alpha^2 \\right)$")
# plt.ylabel("PDF $\\times 10^4$")
# plt.xlabel("$u$ (m$\\,$/s)")
# plt.xlim(left=-5500, right=5500)
# plt.legend()
# plt.show()

# %%
plt.figure()
plt.hist(data["v_x"],bins=75)
plt.show()

# %%
temperature = 3 / 2 * data["mass"][0] * np.sum(np.sqrt(data["v_x"]**2 + data["v_y"]**2 * data["v_z"]**2))
